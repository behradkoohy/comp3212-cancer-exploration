# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %%
def get_datasets():
    # My python only likes absolute paths 
    brca = pd.read_csv('C:\\Users\\sohai\\PycharmProjects\\comp3212-cancer-exploration\\data\\Gistic2_CopyNumber_BRCA', sep='\t')
    ovca = pd.read_csv('C:\\Users\sohai\\PycharmProjects\\comp3212-cancer-exploration\\data\\Gistic2_CopyNumber_OVCA', sep='\t')
    brca.set_index('Gene Symbol', inplace=True)
    ovca.set_index('Gene Symbol', inplace=True)
    brca = brca.transpose()
    ovca = ovca.transpose()
    brca['BRCA'] = 1
    ovca['BRCA'] = 0
    df = pd.concat([brca, ovca[1:]])
    print(len(df), len(brca.transpose()-2) + len(ovca.transpose()-2))
    return df
df = get_datasets()
# Out:
# 1658 49554

# %%
y = df["BRCA"]
X = df[df.columns[:-1]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=24776, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def create_model_PCA():
    model = Sequential()
    model.add(Dense(12, input_dim=997, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = create_model()
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 1110/1110 [==============================] - 1s 1ms/step - loss: 0.0872 - accuracy: 0.8865
# Epoch 2/150
# 1110/1110 [==============================] - 1s 782us/step - loss: 0.0397 - accuracy: 0.9532
# Epoch 3/150
# 1110/1110 [==============================] - 1s 756us/step - loss: 0.0252 - accuracy: 0.9694
# Epoch 4/150
# 1110/1110 [==============================] - 1s 722us/step - loss: 0.0199 - accuracy: 0.9730
# Epoch 5/150
# 1110/1110 [==============================] - 1s 752us/step - loss: 0.0202 - accuracy: 0.9748
# Epoch 6/150
# 1110/1110 [==============================] - 1s 745us/step - loss: 0.0127 - accuracy: 0.9883
# Epoch 7/150
# 1110/1110 [==============================] - 1s 736us/step - loss: 0.0125 - accuracy: 0.9865
# Epoch 8/150
# 1110/1110 [==============================] - 1s 740us/step - loss: 0.0121 - accuracy: 0.9847
# Epoch 9/150
# 1110/1110 [==============================] - 1s 788us/step - loss: 0.0133 - accuracy: 0.9838
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 548/548 [==============================] - 0s 368us/step
# Accuracy: 94.34

# %%
# PCA and train now
x = 0.9999
pca = PCA(n_components=0.99)
pca.fit(X_train)
X_pca = pca.transform(X)
pca = PCA(n_components=x)
pca.fit(X_train)
X_pca = pca.transform(X)
print('at', x, '% of the variance ======')
print("original shape:   ", X.shape)
print("transformed shape:", X_pca.shape)
y_red = pd.Series(y)

df_redd = pd.DataFrame(X_pca)
# Out:
# at 0.9999 % of the variance ======
# original shape:    (1658, 24776)
# transformed shape: (1658, 997)

# %%
model_PCA = create_model_PCA()
X_traind, X_testd, y_traind, y_testd = train_test_split(df_redd, y)

model_PCA.fit(X_traind, y_traind, epochs=150, batch_size=8)
# Out:
# Epoch 1/150
# 1243/1243 [==============================] - 1s 649us/step - loss: 0.1435 - accuracy: 0.8037
# Epoch 2/150
# 1243/1243 [==============================] - 0s 317us/step - loss: 0.0331 - accuracy: 0.9646
# Epoch 3/150
# 1243/1243 [==============================] - 0s 317us/step - loss: 0.0159 - accuracy: 0.9855
# Epoch 4/150
# 1243/1243 [==============================] - 0s 308us/step - loss: 0.0095 - accuracy: 0.9928
# Epoch 5/150
# 1243/1243 [==============================] - 0s 308us/step - loss: 0.0066 - accuracy: 0.9936
# Epoch 6/150
# 1243/1243 [==============================] - 0s 313us/step - loss: 0.0046 - accuracy: 0.9960
# Epoch 7/150
# 1243/1243 [==============================] - 0s 312us/step - loss: 0.0035 - accuracy: 0.9976
# Epoch 8/150
# 1243/1243 [==============================] - 0s 305us/step - loss: 0.0030 - accuracy: 0.9976
# Epoch 9/150
# 1243/1243 [==============================] - 0s 332us/step - loss: 0.0028 - accuracy: 0.9976
# Epoch 10/150
# ...

# %%
_, accuracy = model_PCA.evaluate(X_testd, y_testd)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 415/415 [==============================] - 0s 893us/step
# Accuracy: 95.18

# %%
import eli5
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from eli5.sklearn import PermutationImportance



my_model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=10,verbose=0)    
my_model.fit(X,y)
perm = PermutationImportance(my_model, random_state=1).fit(X,y)
eli5.show_weights(perm, feature_names = df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-127-27a1ea829fff> in <module>
#       6
#       7 my_model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=10,verbose=0)
# ----> 8 my_model.fit(X,y)
#       9 perm = PermutationImportance(my_model, random_state=1).fit(X,y)
#      10 eli5.show_weights(perm, feature_names = df.columns.tolist())
#
# ~\Anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     149         fit_args.update(kwargs)
#     150
# --> 151         history = self.model.fit(x, y, **fit_args)
#     152
#     153         return history
#
# ...

# %%
eli5.show_weights(perm, feature_names = X.columns.tolist(), top = 1000)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AMOTL1
#             </td>
# ...

# %%
import eli5
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from eli5.sklearn import PermutationImportance



my_model = KerasRegressor(build_fn=create_model_PCA, epochs=100, batch_size=10,verbose=0)    
my_model.fit(df_redd,y_red)
perm = PermutationImportance(my_model, random_state=1).fit(df_redd,y_red)
eli5.show_weights(perm)
# Out:
# WARNING:tensorflow:From C:\Users\sohai\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\sohai\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\sohai\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
# ...
